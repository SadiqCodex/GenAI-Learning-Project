# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor, plot_tree
from mlxtend.plotting import plot_decision_regions
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.tree import plot_tree
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score
from sklearn.neighbors import KNeighborsClassifier

# %%
dataset = pd.read_csv("../datasets/subscription_dataset.csv")

# %%
dataset.columns = dataset.columns.str.strip()
dataset.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   56            40342          0
# 1   46           121308          1
# 2   32           121081          1
# 3   25           104045          1
# 4   38            49698          0

# %%
dataset.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
sns.scatterplot(x="Age",y="EstimatedSalary",data=dataset,hue="Purchased")
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
x = dataset.iloc[:,:-1]
y = dataset["Purchased"]

# %%
sc= StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=21)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=21)

# %%
knn.score(x_test,y_test)*100
# Out:
# 85.0

# %%
knn.score(x_train,y_train)*100
# Out:
# 83.75

# %%
for i in range(1,30):
    knn1 = KNeighborsClassifier(n_neighbors=i)
    knn1.fit(x_train,y_train)
    print(i, knn1.score(x_train,y_train)*100,knn1.score(x_test,y_test)*100)
# Out:
# 1 100.0 67.5
# 2 86.25 75.0
# 3 85.0 75.0
# 4 81.875 77.5
# 5 81.875 75.0
# 6 84.375 67.5
# 7 83.75 77.5
# 8 83.125 77.5
# 9 82.5 77.5
# 10 82.5 77.5
# 11 83.125 80.0
# 12 82.5 80.0
# 13 81.875 77.5
# 14 82.5 77.5
# 15 81.25 75.0
# 16 81.875 82.5
# 17 81.875 82.5
# 18 81.875 82.5
# 19 83.125 82.5
# 20 81.875 85.0
# 21 83.75 85.0
# 22 82.5 85.0
# 23 83.125 82.5
# 24 83.125 85.0
# 25 82.5 85.0
# 26 81.875 85.0
# 27 81.875 77.5
# 28 81.25 77.5
# 29 81.25 77.5

# %%
knn.predict([[ -0.371030  ,1.333882]])
# Out:
# c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
x,y
# Out:
# (          Age  EstimatedSalary
#  0    1.378737        -1.120218
#  1    0.583388         0.851214
#  2   -0.530100         0.845687
#  3   -1.086844         0.430879
#  4   -0.052891        -0.892410
#  ..        ...              ...
#  195 -1.245914        -1.176050
#  196  0.821993         0.651748
#  197 -1.404984         0.633803
#  198 -0.848240        -0.072169
#  199 -0.371030         1.333882
#
#  [200 rows x 2 columns],
#  0      0
#  1      1
#  2      1
#  3      1
#  4      0
#        ..
#  195    0
#  196    1
#  197    1
#  198    1
#  199    1
#  Name: Purchased, Length: 200, dtype: int64)

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=knn)
plt.show()
# Out:
# c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
## feature scaling

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np
import matplotlib.pylab as pltlab
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import FunctionTransformer

# %%
data = pd.read_csv('../datasets/loan_data.csv')
data.head()
# Out:
#    Loan_ID   Customer_Age   Gender   Marital_Status   Dependents  \
# 0  L1000             59.0   Male                             1.0
# 1  L1001             49.0   Female   Single                  1.0
# 2  L1002             35.0   Male     Single                  3.0
# 3  L1003             63.0   Female   Divorced
# 4  L1004             28.0   Male     Single                  2.0
#
#     Education_Level   Employment_Type   Annual_Income   Credit_Score  \
# 0   High School                              146114.0          815.0
# 1   Graduate          Unemployed              81135.0          846.0
# 2   High School                               70108.0          491.0
# 3   Graduate          Salaried               132296.0          348.0
# 4   Graduate          Salaried               114179.0
#
#     Loan_Amount   Loan_Term_Months   Property_Area   Existing_Loan  \
# 0       18403.0               12.0   Urban           Yes
# 1       37097.0               24.0   Urban           No
# 2       18121.0               12.0   Urban           No
# 3       15966.0                      Rural
# 4       38621.0               60.0   Rural           No
#
#     Loan_Approval_Status   Application_Date   Last_Payment_Date  \
# 0                          2025-11-24         2025-10-02
# 1   Approved               2025-02-27         2025-03-05
# 2   Rejected               2025-01-13         2025-07-13
# 3   Approved               2025-05-21         2025-02-10
# 4                          2025-05-06
#
#     Interest_Rate   Number_of_Payments   Account_Balance Contact_Method
# 0                                                 1404.0
# 1           11.0                                 41943.0         Branch
# 2           12.08                 37.0                           Branch
# 3           12.39                 19.0           30189.0         Branch
# 4           10.53                 39.0           13763.0          Phone

# %%
data.isnull().sum()
# Out:
# Loan_ID                 0
# Customer_Age            0
# Gender                  0
# Marital_Status          0
# Dependents              0
# Education_Level         0
# Employment_Type         0
# Annual_Income           0
# Credit_Score            0
# Loan_Amount             0
# Loan_Term_Months        0
# Property_Area           0
# Existing_Loan           0
# Loan_Approval_Status    0
# Application_Date        0
# Last_Payment_Date       0
# Interest_Rate           0
# Number_of_Payments      0
# Account_Balance         0
# Contact_Method          0
# dtype: int64

# %%
data["Annual_Income"].fillna(data["Annual_Income"].mean(),inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 data["Annual_Income"].fillna(data["Annual_Income"].mean(),inplace=True)
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6473     # GH#47500 - change to TypeError to match other methods
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string '      146114.0       81135.0       70108.0      132296.0      114179.0                                   43328.0      139181.0      111412.0      106831.0       23987.0                     42399.0      148391.0       66214.0      119522.0      106416.0       90271.0       64064.0      145615.0       90091.0      127450.0       60818.0       65525.0       39830.0                     26893.0      136381.0       99909.0       67333.0                     94290.0       96213.0       25895.0       39738.0       50746.0       69377.0       68404.0       74045.0                    149307.0       59790.0      127455.0       25600.0      114660.0      113179.0       60764.0                     65714.0' to numeric

# %%
data.isnull().sum()
# Out:
# Loan_ID                 0
# Customer_Age            7
# Gender                  7
# Marital_Status          7
# Dependents              7
# Education_Level         7
# Employment_Type         7
# Annual_Income           0
# Credit_Score            7
# Loan_Amount             7
# Loan_Term_Months        7
# Property_Area           7
# Existing_Loan           7
# Loan_Approval_Status    7
# Application_Date        7
# Last_Payment_Date       7
# Interest_Rate           7
# Number_of_Payments      7
# Account_Balance         7
# Contact_Method          7
# dtype: int64

# %%
sns.displot(data['Annual_Income'],kde=True)
plt.show()

# %%
data.describe()
# Out:
#        Customer_Age  Dependents  Annual_Income  Credit_Score   Loan_Amount  \
# count     43.000000   43.000000      50.000000     43.000000     43.000000
# mean      43.488372    2.162791   86066.744186    558.930233  26208.209302
# std       12.075895    1.413038   35063.119390    168.560205  11564.728942
# min       22.000000    0.000000   23987.000000    316.000000   6150.000000
# 25%       35.500000    1.000000   64429.250000    421.000000  17043.500000
# 50%       44.000000    2.000000   86066.744186    545.000000  26606.000000
# 75%       51.500000    3.000000  112737.250000    695.500000  35519.000000
# max       64.000000    4.000000  149307.000000    846.000000  47675.000000
#
#        Loan_Term_Months  Interest_Rate  Number_of_Payments  Account_Balance
# count         43.000000      43.000000           43.000000        43.000000
# mean          37.395349       8.946977           36.302326     25792.511628
# std           17.800668       2.459198           13.871064     14247.150464
# min           12.000000       4.590000           12.000000      1404.000000
# 25%           24.000000       7.145000           24.000000     14109.500000
# 50%           36.000000       8.970000           38.000000     24574.000000
# 75%           54.000000      11.225000           45.500000     39250.500000
# max           60.000000      12.440000           60.000000     49212.000000

# %%
ss = StandardScaler()
ss.fit(data[['Annual_Income']])
# Out:
# StandardScaler()

# %%
data['Annual_Income_ss'] = pd.DataFrame(ss.transform(data[['Annual_Income']]), columns=['x'])

# %%
data.head()
# Out:
#   Loan_ID  Customer_Age  Gender Marital_Status  Dependents Education_Level  \
# 0   L1000          59.0    Male            NaN         1.0     High School
# 1   L1001          49.0  Female         Single         1.0        Graduate
# 2   L1002          35.0    Male         Single         3.0     High School
# 3   L1003          63.0  Female       Divorced         NaN        Graduate
# 4   L1004          28.0    Male         Single         2.0        Graduate
#
#   Employment_Type  Annual_Income  Credit_Score  Loan_Amount  ...  \
# 0             NaN       146114.0         815.0      18403.0  ...
# 1      Unemployed        81135.0         846.0      37097.0  ...
# 2             NaN        70108.0         491.0      18121.0  ...
# 3        Salaried       132296.0         348.0      15966.0  ...
# 4        Salaried       114179.0           NaN      38621.0  ...
#
#    Property_Area Existing_Loan Loan_Approval_Status Application_Date  \
# 0          Urban           Yes                  NaN       2025-11-24
# 1          Urban            No             Approved       2025-02-27
# 2          Urban            No             Rejected       2025-01-13
# 3          Rural           NaN             Approved       2025-05-21
# 4          Rural            No                  NaN       2025-05-06
#
#   Last_Payment_Date Interest_Rate  Number_of_Payments  Account_Balance  \
# 0        2025-10-02           NaN                 NaN           1404.0
# 1        2025-03-05         11.00                 NaN          41943.0
# 2        2025-07-13         12.08                37.0              NaN
# 3        2025-02-10         12.39                19.0          30189.0
# 4               NaN         10.53                39.0          13763.0
#
#    Contact_Method Annual_Income_ss
# 0             NaN         1.729934
# 1          Branch        -0.142081
# 2          Branch        -0.459764
# 3          Branch         1.331844
# 4           Phone         0.809901
#
# [5 rows x 21 columns]

# %%
data.describe()
data.columns = data.columns.str.strip()
# Out:
#        Customer_Age  Dependents  Annual_Income  Credit_Score   Loan_Amount  \
# count     43.000000   43.000000      50.000000     43.000000     43.000000
# mean      43.488372    2.162791   86066.744186    558.930233  26208.209302
# std       12.075895    1.413038   35063.119390    168.560205  11564.728942
# min       22.000000    0.000000   23987.000000    316.000000   6150.000000
# 25%       35.500000    1.000000   64429.250000    421.000000  17043.500000
# 50%       44.000000    2.000000   86066.744186    545.000000  26606.000000
# 75%       51.500000    3.000000  112737.250000    695.500000  35519.000000
# max       64.000000    4.000000  149307.000000    846.000000  47675.000000
#
#        Loan_Term_Months  Interest_Rate  Number_of_Payments  Account_Balance  \
# count         43.000000      43.000000           43.000000        43.000000
# mean          37.395349       8.946977           36.302326     25792.511628
# std           17.800668       2.459198           13.871064     14247.150464
# min           12.000000       4.590000           12.000000      1404.000000
# 25%           24.000000       7.145000           24.000000     14109.500000
# 50%           36.000000       8.970000           38.000000     24574.000000
# 75%           54.000000      11.225000           45.500000     39250.500000
# max           60.000000      12.440000           60.000000     49212.000000
#
#        Annual_Income_ss
# count      5.000000e+01
# mean      -1.887379e-16
# std        1.010153e+00
# min       -1.788489e+00
# 25%       -6.233664e-01
# 50%        0.000000e+00
# 75%        7.683652e-01
# max        1.821923e+00

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.title('Annual Income Before')
sns.distplot(data['Annual_Income'])
plt.subplot(1,2,2)
plt.title('Annual Income After')
sns.distplot(data['Annual_Income_ss'])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22916\3247783563.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_22916\3247783563.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income_ss'])

# %%
data.describe()
# Out:
#        Customer_Age  Dependents  Annual_Income  Credit_Score   Loan_Amount  \
# count     43.000000   43.000000      50.000000     43.000000     43.000000
# mean      43.488372    2.162791   86066.744186    558.930233  26208.209302
# std       12.075895    1.413038   35063.119390    168.560205  11564.728942
# min       22.000000    0.000000   23987.000000    316.000000   6150.000000
# 25%       35.500000    1.000000   64429.250000    421.000000  17043.500000
# 50%       44.000000    2.000000   86066.744186    545.000000  26606.000000
# 75%       51.500000    3.000000  112737.250000    695.500000  35519.000000
# max       64.000000    4.000000  149307.000000    846.000000  47675.000000
#
#        Loan_Term_Months  Interest_Rate  Number_of_Payments  Account_Balance  \
# count         43.000000      43.000000           43.000000        43.000000
# mean          37.395349       8.946977           36.302326     25792.511628
# std           17.800668       2.459198           13.871064     14247.150464
# min           12.000000       4.590000           12.000000      1404.000000
# 25%           24.000000       7.145000           24.000000     14109.500000
# 50%           36.000000       8.970000           38.000000     24574.000000
# 75%           54.000000      11.225000           45.500000     39250.500000
# max           60.000000      12.440000           60.000000     49212.000000
#
#        Annual_Income_ss
# count      5.000000e+01
# mean      -1.887379e-16
# std        1.010153e+00
# min       -1.788489e+00
# 25%       -6.233664e-01
# 50%        0.000000e+00
# 75%        7.683652e-01
# max        1.821923e+00

# %%
sns.distplot(data['Annual_Income'])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22916\2833962190.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income'])

# %%
ms = MinMaxScaler()
ms.fit(data[['Annual_Income']])
# Out:
# MinMaxScaler()

# %%
data['Annual_Income_min'] = ms.transform(data[['Annual_Income']])

# %%
data.head()
# Out:
#   Loan_ID  Customer_Age  Gender Marital_Status  Dependents Education_Level  \
# 0   L1000          59.0    Male            NaN         1.0     High School
# 1   L1001          49.0  Female         Single         1.0        Graduate
# 2   L1002          35.0    Male         Single         3.0     High School
# 3   L1003          63.0  Female       Divorced         NaN        Graduate
# 4   L1004          28.0    Male         Single         2.0        Graduate
#
#   Employment_Type  Annual_Income  Credit_Score  Loan_Amount  ...  \
# 0             NaN       146114.0         815.0      18403.0  ...
# 1      Unemployed        81135.0         846.0      37097.0  ...
# 2             NaN        70108.0         491.0      18121.0  ...
# 3        Salaried       132296.0         348.0      15966.0  ...
# 4        Salaried       114179.0           NaN      38621.0  ...
#
#    Existing_Loan Loan_Approval_Status Application_Date Last_Payment_Date  \
# 0            Yes                  NaN       2025-11-24        2025-10-02
# 1             No             Approved       2025-02-27        2025-03-05
# 2             No             Rejected       2025-01-13        2025-07-13
# 3            NaN             Approved       2025-05-21        2025-02-10
# 4             No                  NaN       2025-05-06               NaN
#
#   Interest_Rate Number_of_Payments  Account_Balance  Contact_Method  \
# 0           NaN                NaN           1404.0             NaN
# 1         11.00                NaN          41943.0          Branch
# 2         12.08               37.0              NaN          Branch
# 3         12.39               19.0          30189.0          Branch
# 4         10.53               39.0          13763.0           Phone
#
#    Annual_Income_ss Annual_Income_min
# 0          1.729934          0.974521
# 1         -0.142081          0.456017
# 2         -0.459764          0.368026
# 3          1.331844          0.864259
# 4          0.809901          0.719694
#
# [5 rows x 22 columns]

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title("before")
sns.distplot(data['Annual_Income'])

plt.subplot(1,2,2)
plt.title("after")
sns.distplot(data['Annual_Income_min'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22916\97496108.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_22916\97496108.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income_min'])
# <Axes: title={'center': 'after'}, xlabel='Annual_Income_min', ylabel='Density'>

# %%
new_data = {"name":["a","b","c","d","e","a","c"], "eng":[5,3,2,4,6,5,3],'hindi':[2,3,4,5,3,2,4]}

# %%
df = pd.DataFrame(new_data)
df
# Out:
#   name  eng  hindi
# 0    a    5      2
# 1    b    3      3
# 2    c    2      4
# 3    d    4      5
# 4    e    6      3
# 5    a    5      2
# 6    c    3      4

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#   name  eng  hindi
# 0    a    5      2
# 1    b    3      3
# 2    c    2      4
# 3    d    4      5
# 4    e    6      3
# 6    c    3      4

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
data.shape
# Out:
# (50, 22)

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (50, 22)

# %%
data.head()
# Out:
#   Loan_ID  Customer_Age  Gender Marital_Status  Dependents Education_Level  \
# 0   L1000          59.0    Male            NaN         1.0     High School
# 1   L1001          49.0  Female         Single         1.0        Graduate
# 2   L1002          35.0    Male         Single         3.0     High School
# 3   L1003          63.0  Female       Divorced         NaN        Graduate
# 4   L1004          28.0    Male         Single         2.0        Graduate
#
#   Employment_Type  Annual_Income  Credit_Score  Loan_Amount  ...  \
# 0             NaN       146114.0         815.0      18403.0  ...
# 1      Unemployed        81135.0         846.0      37097.0  ...
# 2             NaN        70108.0         491.0      18121.0  ...
# 3        Salaried       132296.0         348.0      15966.0  ...
# 4        Salaried       114179.0           NaN      38621.0  ...
#
#    Existing_Loan Loan_Approval_Status Application_Date Last_Payment_Date  \
# 0            Yes                  NaN       2025-11-24        2025-10-02
# 1             No             Approved       2025-02-27        2025-03-05
# 2             No             Rejected       2025-01-13        2025-07-13
# 3            NaN             Approved       2025-05-21        2025-02-10
# 4             No                  NaN       2025-05-06               NaN
#
#   Interest_Rate Number_of_Payments  Account_Balance  Contact_Method  \
# 0           NaN                NaN           1404.0             NaN
# 1         11.00                NaN          41943.0          Branch
# 2         12.08               37.0              NaN          Branch
# 3         12.39               19.0          30189.0          Branch
# 4         10.53               39.0          13763.0           Phone
#
#    Annual_Income_ss Annual_Income_min
# 0          1.729934          0.974521
# 1         -0.142081          0.456017
# 2         -0.459764          0.368026
# 3          1.331844          0.864259
# 4          0.809901          0.719694
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Loan_ID                50 non-null     object
#  1    Customer_Age          50 non-null     object
#  2    Gender                50 non-null     object
#  3    Marital_Status        50 non-null     object
#  4    Dependents            50 non-null     object
#  5    Education_Level       50 non-null     object
#  6    Employment_Type       50 non-null     object
#  7    Annual_Income         50 non-null     object
#  8    Credit_Score          50 non-null     object
#  9    Loan_Amount           50 non-null     object
#  10   Loan_Term_Months      50 non-null     object
#  11   Property_Area         50 non-null     object
#  12   Existing_Loan         50 non-null     object
#  13   Loan_Approval_Status  50 non-null     object
#  14   Application_Date      50 non-null     object
#  15   Last_Payment_Date     50 non-null     object
#  16   Interest_Rate         50 non-null     object
#  17   Number_of_Payments    50 non-null     object
#  18   Account_Balance       50 non-null     object
#  19   Contact_Method        50 non-null     object
# dtypes: object(20)
# memory usage: 7.9+ KB

# %%
data.isnull().sum()
# Out:
# Loan_ID                  0
#  Customer_Age            0
#  Gender                  0
#  Marital_Status          0
#  Dependents              0
#  Education_Level         0
#  Employment_Type         0
#  Annual_Income           0
#  Credit_Score            0
#  Loan_Amount             0
#  Loan_Term_Months        0
#  Property_Area           0
#  Existing_Loan           0
#  Loan_Approval_Status    0
#  Application_Date        0
#  Last_Payment_Date       0
#  Interest_Rate           0
#  Number_of_Payments      0
#  Account_Balance         0
#  Contact_Method          0
# dtype: int64

# %%
data[' Dependents'].value_counts()
# Remove leading/trailing spaces from column names
data.columns = data.columns.str.strip()

# %%
# Replace empty strings with NaN
data['Dependents'].replace(r'^\s*$', np.nan, regex=True, inplace=True)

# Fill missing values with mode
data['Dependents'].fillna(data['Dependents'].mode()[0], inplace=True)

# Convert to numeric
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12892\2333858441.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Dependents'].replace(r'^\s*$', np.nan, regex=True, inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_12892\2333858441.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Dependents'].fillna(data['Dependents'].mode()[0], inplace=True)

# %%
data['Dependents'].value_counts()
# Out:
# Dependents
# 3.0    17
# 2.0     8
# 0.0     8
# 4.0     8
# 1.0     6
# 9.0     1
# 6.0     1
# 3+      1
# Name: count, dtype: int64

# %%
data['Dependents'].replace('        3+', '3.0',inplace=True)

# %%
data['Dependents'].value_counts()
# Out:
# Dependents
#         3.0    17
#         2.0     8
#         0.0     8
#         4.0     8
#         1.0     6
#         9.0     1
#         6.0     1
# 3.0             1
# Name: count, dtype: int64

# %%
data.head(50)
# Out:
#     Loan_ID   Customer_Age   Gender   Marital_Status   Dependents  \
# 0   L1000             59.0   Male                             1.0
# 1   L1001             49.0   Female   Single                  1.0
# 2   L1002             35.0   Male     Single                  3.0
# 3   L1003             63.0   Female   Divorced                3.0
# 4   L1004             28.0   Male     Single                  2.0
# 5   L1005             41.0   Female   Single                  0.0
# 6   L1006             59.0   Male                             3.0
# 7   L1007             39.0   Male     Divorced                4.0
# 8   L1008             43.0   Female   Single                  3.0
# 9   L1009             31.0   Male     Single                  4.0
# 10  L1010             31.0            Divorced                4.0
# 11  L1011             44.0   Female   Divorced                2.0
# 12  L1012             56.0   Female   Divorced                4.0
# 13  L1013             60.0                                    3.0
# 14  L1014             44.0   Female   Divorced                4.0
# 15  L1015             23.0            Divorced                3.0
# 16  L1016             42.0   Female   Single                  2.0
# 17  L1017             22.0   Female   Divorced                3.0
# 18  L1018             44.0            Single                  1.0
# 19  L1019             64.0   Female   Married                 1.0
# 20  L1020             50.0   Female   Divorced                4.0
# 21  L1021             58.0   Male     Married                 9.0
# 22  L1022                    Male                             4.0
# 23  L1023             41.0            Divorced                3.0
# 24  L1024             53.0   Female   Single                  3.0
# 25  L1025             32.0   Female   Married                 3.0
# 26  L1026             42.0   Female   Single                  3.0
# 27  L1027             64.0   Female   Divorced                3.0
# 28  L1028             45.0   Female   Divorced                2.0
# 29  L1029             47.0   Female   Married                 1.0
# 30  L1030                    Female   Single                  3.0
# 31  L1031             48.0   Male     Divorced                0.0
# 32  L1032             36.0   Female   Married                 0.0
# 33  L1033                    Male     Divorced                0.0
# 34  L1034                    Female   Divorced                3.0
# 35  L1035             23.0   Female   Single                  2.0
# 36  L1036             57.0   Male     Divorced                0.0
# 37  L1037                    Female   Single                  3.0
# 38  L1038             41.0   Male     Divorced                4.0
# 39  L1039                    Female                           3.0
# 40  L1040             59.0   Female   Divorced                2.0
# 41  L1041             38.0   Male     Single                  2.0
# 42  L1042             24.0   Female   Single                  0.0
# 43  L1043             45.0   Male     Married                 6.0
# 44  L1044             34.0   Female   Divorced                0.0
# 45  L1045                    Male                             2.0
# 46  L1046             46.0   Male     Married                 1.0
# 47  L1047             22.0            Divorced                3.0
# 48  L1048             40.0   Female                           3.0
# 49  L1049             48.0            Single                  0.0
#
#      Education_Level   Employment_Type   Annual_Income   Credit_Score  \
# 0    High School                              146114.0          815.0
# 1    Graduate          Unemployed              81135.0          846.0
# 2    High School                               70108.0          491.0
# 3    Graduate          Salaried               132296.0          348.0
# 4    Graduate          Salaried               114179.0
# 5    Postgraduate      Unemployed                               316.0
# 6    Graduate          Self-employed                            471.0
# 7    Postgraduate      Salaried                43328.0          519.0
# 8                                             139181.0          457.0
# 9    High School       Salaried               111412.0
# 10   High School       Salaried               106831.0          345.0
# 11                     Self-employed           23987.0
# 12                     Unemployed                               817.0
# 13   High School       Unemployed              42399.0          398.0
# 14   Graduate          Self-employed          148391.0          336.0
# 15                     Self-employed           66214.0          579.0
# 16   Graduate          Unemployed             119522.0          648.0
# 17   Postgraduate      Unemployed             106416.0
# 18   High School       Self-employed           90271.0          601.0
# 19   High School       Salaried                64064.0          480.0
# 20   High School                              145615.0          398.0
# 21                     Self-employed           90091.0          415.0
# 22   Graduate                                 127450.0          490.0
# 23                     Self-employed           60818.0          552.0
# 24   High School                               65525.0          460.0
# 25   Graduate          Salaried                39830.0          555.0
# 26   Graduate          Unemployed                               622.0
# 27   Postgraduate      Unemployed              26893.0          427.0
# 28   Postgraduate      Salaried               136381.0          317.0
# 29   Postgraduate      Salaried                99909.0          622.0
# 30   Postgraduate      Unemployed              67333.0
# 31   High School       Unemployed                               454.0
# 32   Postgraduate      Unemployed              94290.0          789.0
# 33   Graduate          Self-employed           96213.0          685.0
# 34   High School       Salaried                25895.0          403.0
# 35   Graduate          Unemployed              39738.0          692.0
# 36   Graduate          Salaried                50746.0          545.0
# 37   Graduate          Self-employed           69377.0          475.0
# 38   Postgraduate      Self-employed           68404.0
# 39   Postgraduate      Unemployed              74045.0          776.0
# 40   High School       Self-employed
# 41   High School       Salaried               149307.0          707.0
# 42   Postgraduate      Unemployed              59790.0          824.0
# 43                     Salaried               127455.0          805.0
# 44   High School       Salaried                25600.0          335.0
# 45   Postgraduate      Self-employed          114660.0          319.0
# 46   Postgraduate      Self-employed          113179.0          620.0
# 47   Postgraduate                              60764.0          811.0
# 48   Graduate          Self-employed                            699.0
# 49   Postgraduate      Self-employed           65714.0          770.0
#
#      Loan_Amount   Loan_Term_Months   Property_Area   Existing_Loan  \
# 0        18403.0               12.0   Urban           Yes
# 1        37097.0               24.0   Urban           No
# 2        18121.0               12.0   Urban           No
# 3        15966.0                      Rural
# 4        38621.0               60.0   Rural           No
# 5        33312.0               12.0   Urban           No
# 6        27677.0               60.0   Rural           Yes
# 7        36289.0               60.0   Urban           No
# 8                              60.0                   Yes
# 9        47675.0               36.0   Semiurban       Yes
# 10        9777.0               48.0   Rural           Yes
# 11       34749.0               24.0   Urban           Yes
# 12                                    Urban
# 13        7491.0               60.0   Rural           Yes
# 14       32236.0               12.0
# 15       19599.0                      Semiurban       No
# 16       24508.0               48.0   Urban           Yes
# 17                             60.0   Rural           Yes
# 18       26606.0               12.0   Semiurban       No
# 19       26699.0               48.0                   No
# 20                             60.0   Rural           No
# 21       37093.0               48.0   Urban           Yes
# 22        9142.0               24.0   Semiurban
# 23       20202.0               24.0   Urban           Yes
# 24       44734.0                      Semiurban       Yes
# 25       12079.0               48.0   Semiurban       Yes
# 26       12987.0               12.0   Semiurban       Yes
# 27       44567.0               60.0                   No
# 28       33940.0               24.0   Semiurban
# 29       42233.0               24.0   Rural           Yes
# 30       22019.0               60.0   Urban
# 31       23077.0                      Rural           Yes
# 32       31258.0               24.0                   No
# 33       26136.0               48.0   Urban           Yes
# 34       13311.0               24.0   Semiurban       Yes
# 35       22214.0               24.0   Urban           No
# 36       19098.0               36.0   Rural           No
# 37                             24.0   Urban           Yes
# 38       42945.0                                      No
# 39                             60.0   Urban           No
# 40       30316.0               60.0   Urban           Yes
# 41       37217.0                      Urban           No
# 42       13308.0               24.0   Semiurban       Yes
# 43       10949.0               12.0
# 44        6150.0               48.0   Urban           Yes
# 45       28944.0               36.0   Rural           Yes
# 46       39699.0               48.0   Urban           Yes
# 47       14204.0               48.0   Rural           No
# 48                             24.0   Semiurban       Yes
# 49       34305.0               36.0   Urban           No
#
#      Loan_Approval_Status   Application_Date   Last_Payment_Date  \
# 0                           2025-11-24         2025-10-02
# 1    Approved               2025-02-27         2025-03-05
# 2    Rejected               2025-01-13         2025-07-13
# 3    Approved               2025-05-21         2025-02-10
# 4                           2025-05-06
# 5    Rejected                                  2025-05-31
# 6    Approved               2025-03-13         2025-11-18
# 7    Approved               2025-02-22         2025-11-13
# 8    Approved               2025-12-13         2025-07-05
# 9    Approved               2025-10-07         2025-10-23
# 10   Rejected               2025-02-14         2025-04-09
# 11   Rejected               2025-10-30         2025-12-27
# 12   Approved               2025-08-05         2025-02-05
# 13   Rejected               2025-01-17         2025-01-24
# 14   Approved               2025-01-16         2025-12-05
# 15   Rejected               2025-02-17
# 16   Approved                                  2025-05-29
# 17   Approved               2025-04-30         2025-02-10
# 18   Approved                                  2025-04-30
# 19   Approved               2025-11-05         2025-02-21
# 20   Approved               2025-01-14         2025-07-14
# 21   Approved               2025-10-15         2025-05-23
# 22   Rejected               2025-04-12         2025-08-21
# 23   Approved               2025-11-29         2025-11-22
# 24   Rejected               2025-12-26         2025-07-06
# 25   Approved               2025-10-07         2025-03-25
# 26   Rejected
# 27                          2025-04-23
# 28                          2025-08-18         2025-04-18
# 29   Approved                                  2025-12-10
# 30   Approved               2025-05-23         2025-05-17
# 31   Rejected               2025-01-04         2025-12-26
# 32   Approved               2025-03-23         2025-12-16
# 33   Rejected               2025-12-24
# 34   Approved               2025-08-05
# 35   Rejected               2025-06-24         2025-11-08
# 36   Rejected               2025-05-23         2025-11-22
# 37   Approved
# 38                          2025-04-21         2025-10-01
# 39   Approved               2025-06-22         2025-05-06
# 40   Rejected               2025-02-22         2025-03-25
# 41                          2025-02-17         2025-08-25
# 42   Approved               2025-07-14         2025-07-14
# 43   Approved               2025-02-19         2025-05-19
# 44   Approved               2025-07-03         2025-11-24
# 45   Rejected                                  2025-12-19
# 46                          2025-11-06         2025-10-13
# 47   Rejected               2025-05-16         2025-04-23
# 48   Rejected               2025-01-23         2025-12-17
# 49   Approved               2025-08-24         2025-06-16
#
#      Interest_Rate   Number_of_Payments   Account_Balance Contact_Method
# 0                                                  1404.0
# 1            11.0                                 41943.0         Branch
# 2            12.08                 37.0                           Branch
# 3            12.39                 19.0           30189.0         Branch
# 4            10.53                 39.0           13763.0          Phone
# 5             7.51                 39.0           19384.0          Phone
# 6                                  48.0           33606.0          Phone
# 7            10.72                                10860.0
# 8             8.97                 47.0           39757.0          Phone
# 9             7.89                 38.0           16106.0
# 10           11.75                 28.0           24574.0          Phone
# 11            5.39                 20.0           24524.0         Branch
# 12            8.44                 44.0            4636.0         Branch
# 13            4.59                                11916.0         Branch
# 14            8.25                 24.0            5809.0         Branch
# 15                                 39.0           33201.0          Phone
# 16            5.45                 59.0           14456.0          Email
# 17            5.44                                49212.0          Phone
# 18            9.69                 24.0           39765.0          Email
# 19           10.47                 57.0           35816.0         Branch
# 20                                 46.0                            Phone
# 21                                                18100.0         Branch
# 22            7.5                  29.0           22949.0          Phone
# 23            6.79                 16.0            5544.0         Branch
# 24           11.45                 58.0           38744.0
# 25            6.29                 36.0           46543.0          Email
# 26           12.21                 13.0           43783.0
# 27            4.6                  21.0           27657.0          Phone
# 28           12.26                 41.0                            Email
# 29            4.85                 56.0           48198.0          Phone
# 30           11.63                 16.0            8239.0          Email
# 31            8.72                 44.0           15489.0          Email
# 32           12.44                 12.0           44125.0          Phone
# 33                                 29.0           29538.0          Phone
# 34            8.93                 43.0           33049.0          Email
# 35                                 58.0                            Phone
# 36            8.68                                43944.0          Email
# 37            9.54                 22.0            9427.0
# 38           10.07                 32.0           42348.0         Branch
# 39            8.14                 37.0           25285.0         Branch
# 40            9.52                 36.0           38626.0         Branch
# 41            9.17                 33.0                           Branch
# 42           11.71                 38.0           23928.0         Branch
# 43            4.86                 60.0           20198.0          Email
# 44            6.75                 24.0                           Branch
# 45           12.1                  44.0           16254.0         Branch
# 46           11.62                 45.0                           Branch
# 47            8.15                 52.0            2252.0         Branch
# 48            9.46                 46.0           40764.0
# 49            6.72                 12.0           13173.0          Email

# %%
data['Dependents'] = data['Dependents'].astype("float64")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 data[' Dependents'] = data[' Dependents'].astype("float64")
#       2 data['Annual_Income'] = data['Annual_Income'].astype("float64")
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '           '

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Loan_ID                50 non-null     object
#  1    Customer_Age          50 non-null     object
#  2    Gender                50 non-null     object
#  3    Marital_Status        50 non-null     object
#  4    Dependents            50 non-null     object
#  5    Education_Level       50 non-null     object
#  6    Employment_Type       50 non-null     object
#  7    Annual_Income         50 non-null     object
#  8    Credit_Score          50 non-null     object
#  9    Loan_Amount           50 non-null     object
#  10   Loan_Term_Months      50 non-null     object
#  11   Property_Area         50 non-null     object
#  12   Existing_Loan         50 non-null     object
#  13   Loan_Approval_Status  50 non-null     object
#  14   Application_Date      50 non-null     object
#  15   Last_Payment_Date     50 non-null     object
#  16   Interest_Rate         50 non-null     object
#  17   Number_of_Payments    50 non-null     object
#  18   Account_Balance       50 non-null     object
#  19   Contact_Method        50 non-null     object
# dtypes: object(20)
# memory usage: 7.9+ KB

# %%
data.isnull().sum()
# Out:
# Loan_ID                 0
# Customer_Age            0
# Gender                  0
# Marital_Status          0
# Dependents              0
# Education_Level         0
# Employment_Type         0
# Annual_Income           0
# Credit_Score            0
# Loan_Amount             0
# Loan_Term_Months        0
# Property_Area           0
# Existing_Loan           0
# Loan_Approval_Status    0
# Application_Date        0
# Last_Payment_Date       0
# Interest_Rate           0
# Number_of_Payments      0
# Account_Balance         0
# Contact_Method          0
# dtype: int64

# %%
## feature scaling

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np
import matplotlib.pylab as pltlab
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
data = pd.read_csv('../data/loan_data.csv')
data.head()
# Out:
#    Loan_ID   Customer_Age   Gender   Marital_Status   Dependents  \
# 0  L1000             59.0   Male                             1.0
# 1  L1001             49.0   Female   Single                  1.0
# 2  L1002             35.0   Male     Single                  3.0
# 3  L1003             63.0   Female   Divorced
# 4  L1004             28.0   Male     Single                  2.0
#
#     Education_Level   Employment_Type   Annual_Income   Credit_Score  \
# 0   High School                              146114.0          815.0
# 1   Graduate          Unemployed              81135.0          846.0
# 2   High School                               70108.0          491.0
# 3   Graduate          Salaried               132296.0          348.0
# 4   Graduate          Salaried               114179.0
#
#     Loan_Amount   Loan_Term_Months   Property_Area   Existing_Loan  \
# 0       18403.0               12.0   Urban           Yes
# 1       37097.0               24.0   Urban           No
# 2       18121.0               12.0   Urban           No
# 3       15966.0                      Rural
# 4       38621.0               60.0   Rural           No
#
#     Loan_Approval_Status   Application_Date   Last_Payment_Date  \
# 0                          2025-11-24         2025-10-02
# 1   Approved               2025-02-27         2025-03-05
# 2   Rejected               2025-01-13         2025-07-13
# 3   Approved               2025-05-21         2025-02-10
# 4                          2025-05-06
#
#     Interest_Rate   Number_of_Payments   Account_Balance  Contact_Method
# 0                                                 1404.0
# 1           11.0                                 41943.0          Branch
# 2           12.08                 37.0                            Branch
# 3           12.39                 19.0           30189.0          Branch
# 4           10.53                 39.0           13763.0           Phone

# %%
data.isnull().sum()
# Out:
# Loan_ID                  0
#  Customer_Age            0
#  Gender                  0
#  Marital_Status          0
#  Dependents              0
#  Education_Level         0
#  Employment_Type         0
#  Annual_Income           0
#  Credit_Score            0
#  Loan_Amount             0
#  Loan_Term_Months        0
#  Property_Area           0
#  Existing_Loan           0
#  Loan_Approval_Status    0
#  Application_Date        0
#  Last_Payment_Date       0
#  Interest_Rate           0
#  Number_of_Payments      0
#  Account_Balance         0
#  Contact_Method          0
# dtype: int64

# %%
data["Annual_Income"].fillna(data["Annual_Income"].mean(),inplace=True)
# Out:
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#
#    3811 try:
#
# -> 3812     return self._engine.get_loc(casted_key)
#
#    3813 except KeyError as err:
#
#
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
#
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
#
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
#
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
#
#
# KeyError: 'Annual_Income'
#
#
#
# The above exception was the direct cause of the following exception:
#
#
#
# KeyError                                  Traceback (most recent call last)
#
# Cell In[26], line 1
#
# ----> 1 data["Annual_Income"].fillna(data["Annual_Income"].mean(),inplace=True)
#
#
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#
#    4111 if self.columns.nlevels > 1:
#
#    4112     return self._getitem_multilevel(key)
#
# -> 4113 indexer = self.columns.get_loc(key)
#
#    4114 if is_integer(indexer):
#
#    4115     indexer = [indexer]
#
#
#
# File c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#
#    3814     if isinstance(casted_key, slice) or (
#
#    3815         isinstance(casted_key, abc.Iterable)
#
#    3816         and any(isinstance(x, slice) for x in casted_key)
#
#    3817     ):
#
#    3818         raise InvalidIndexError(key)
#
# -> 3819     raise KeyError(key) from err
#
#    3820 except TypeError:
#
#    3821     # If we have a listlike key, _check_indexing_error will raise
#
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#
#    3823     #  the TypeError.
#
#    3824     self._check_indexing_error(key)
#
#
#
# KeyError: 'Annual_Income'

# %%
data.isnull().sum()
# Out:
# Loan_ID                 0
# Customer_Age            7
# Gender                  7
# Marital_Status          7
# Dependents              7
# Education_Level         7
# Employment_Type         7
# Annual_Income           0
# Credit_Score            7
# Loan_Amount             7
# Loan_Term_Months        7
# Property_Area           7
# Existing_Loan           7
# Loan_Approval_Status    7
# Application_Date        7
# Last_Payment_Date       7
# Interest_Rate           7
# Number_of_Payments      7
# Account_Balance         7
# Contact_Method          7
# dtype: int64

# %%
sns.displot(data['Annual_Income'],kde=True)
plt.show()

# %%
data.describe()
# Out:
#        Customer_Age  Dependents  Annual_Income  Credit_Score   Loan_Amount  \
# count     43.000000   43.000000      50.000000     43.000000     43.000000
# mean      43.488372    2.162791   86066.744186    558.930233  26208.209302
# std       12.075895    1.413038   35063.119390    168.560205  11564.728942
# min       22.000000    0.000000   23987.000000    316.000000   6150.000000
# 25%       35.500000    1.000000   64429.250000    421.000000  17043.500000
# 50%       44.000000    2.000000   86066.744186    545.000000  26606.000000
# 75%       51.500000    3.000000  112737.250000    695.500000  35519.000000
# max       64.000000    4.000000  149307.000000    846.000000  47675.000000
#
#        Loan_Term_Months  Interest_Rate  Number_of_Payments  Account_Balance
# count         43.000000      43.000000           43.000000        43.000000
# mean          37.395349       8.946977           36.302326     25792.511628
# std           17.800668       2.459198           13.871064     14247.150464
# min           12.000000       4.590000           12.000000      1404.000000
# 25%           24.000000       7.145000           24.000000     14109.500000
# 50%           36.000000       8.970000           38.000000     24574.000000
# 75%           54.000000      11.225000           45.500000     39250.500000
# max           60.000000      12.440000           60.000000     49212.000000

# %%
ss = StandardScaler()
ss.fit(data[['Annual_Income']])
# Out:
# StandardScaler()

# %%
data['Annual_Income_ss'] = pd.DataFrame(ss.transform(data[['Annual_Income']]), columns=['x'])

# %%
data.head()
# Out:
#   Loan_ID  Customer_Age  Gender Marital_Status  Dependents Education_Level  \
# 0   L1000          59.0    Male            NaN         1.0     High School
# 1   L1001          49.0  Female         Single         1.0        Graduate
# 2   L1002          35.0    Male         Single         3.0     High School
# 3   L1003          63.0  Female       Divorced         NaN        Graduate
# 4   L1004          28.0    Male         Single         2.0        Graduate
#
#   Employment_Type  Annual_Income  Credit_Score  Loan_Amount  ...  \
# 0             NaN       146114.0         815.0      18403.0  ...
# 1      Unemployed        81135.0         846.0      37097.0  ...
# 2             NaN        70108.0         491.0      18121.0  ...
# 3        Salaried       132296.0         348.0      15966.0  ...
# 4        Salaried       114179.0           NaN      38621.0  ...
#
#    Property_Area Existing_Loan Loan_Approval_Status Application_Date  \
# 0          Urban           Yes                  NaN       2025-11-24
# 1          Urban            No             Approved       2025-02-27
# 2          Urban            No             Rejected       2025-01-13
# 3          Rural           NaN             Approved       2025-05-21
# 4          Rural            No                  NaN       2025-05-06
#
#   Last_Payment_Date Interest_Rate  Number_of_Payments  Account_Balance  \
# 0        2025-10-02           NaN                 NaN           1404.0
# 1        2025-03-05         11.00                 NaN          41943.0
# 2        2025-07-13         12.08                37.0              NaN
# 3        2025-02-10         12.39                19.0          30189.0
# 4               NaN         10.53                39.0          13763.0
#
#    Contact_Method Annual_Income_ss
# 0             NaN         1.729934
# 1          Branch        -0.142081
# 2          Branch        -0.459764
# 3          Branch         1.331844
# 4           Phone         0.809901
#
# [5 rows x 21 columns]

# %%
data.describe()
data.columns = data.columns.str.strip()
# Out:
#        Customer_Age  Dependents  Annual_Income  Credit_Score   Loan_Amount  \
# count     43.000000   43.000000      50.000000     43.000000     43.000000
# mean      43.488372    2.162791   86066.744186    558.930233  26208.209302
# std       12.075895    1.413038   35063.119390    168.560205  11564.728942
# min       22.000000    0.000000   23987.000000    316.000000   6150.000000
# 25%       35.500000    1.000000   64429.250000    421.000000  17043.500000
# 50%       44.000000    2.000000   86066.744186    545.000000  26606.000000
# 75%       51.500000    3.000000  112737.250000    695.500000  35519.000000
# max       64.000000    4.000000  149307.000000    846.000000  47675.000000
#
#        Loan_Term_Months  Interest_Rate  Number_of_Payments  Account_Balance  \
# count         43.000000      43.000000           43.000000        43.000000
# mean          37.395349       8.946977           36.302326     25792.511628
# std           17.800668       2.459198           13.871064     14247.150464
# min           12.000000       4.590000           12.000000      1404.000000
# 25%           24.000000       7.145000           24.000000     14109.500000
# 50%           36.000000       8.970000           38.000000     24574.000000
# 75%           54.000000      11.225000           45.500000     39250.500000
# max           60.000000      12.440000           60.000000     49212.000000
#
#        Annual_Income_ss
# count      5.000000e+01
# mean      -1.887379e-16
# std        1.010153e+00
# min       -1.788489e+00
# 25%       -6.233664e-01
# 50%        0.000000e+00
# 75%        7.683652e-01
# max        1.821923e+00

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.title('Annual Income Before')
sns.distplot(data['Annual_Income'])
plt.subplot(1,2,2)
plt.title('Annual Income After')
sns.distplot(data['Annual_Income_ss'])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22916\3247783563.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_22916\3247783563.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income_ss'])

# %%
data.describe()
# Out:
#        Customer_Age  Dependents  Annual_Income  Credit_Score   Loan_Amount  \
# count     43.000000   43.000000      50.000000     43.000000     43.000000
# mean      43.488372    2.162791   86066.744186    558.930233  26208.209302
# std       12.075895    1.413038   35063.119390    168.560205  11564.728942
# min       22.000000    0.000000   23987.000000    316.000000   6150.000000
# 25%       35.500000    1.000000   64429.250000    421.000000  17043.500000
# 50%       44.000000    2.000000   86066.744186    545.000000  26606.000000
# 75%       51.500000    3.000000  112737.250000    695.500000  35519.000000
# max       64.000000    4.000000  149307.000000    846.000000  47675.000000
#
#        Loan_Term_Months  Interest_Rate  Number_of_Payments  Account_Balance  \
# count         43.000000      43.000000           43.000000        43.000000
# mean          37.395349       8.946977           36.302326     25792.511628
# std           17.800668       2.459198           13.871064     14247.150464
# min           12.000000       4.590000           12.000000      1404.000000
# 25%           24.000000       7.145000           24.000000     14109.500000
# 50%           36.000000       8.970000           38.000000     24574.000000
# 75%           54.000000      11.225000           45.500000     39250.500000
# max           60.000000      12.440000           60.000000     49212.000000
#
#        Annual_Income_ss
# count      5.000000e+01
# mean      -1.887379e-16
# std        1.010153e+00
# min       -1.788489e+00
# 25%       -6.233664e-01
# 50%        0.000000e+00
# 75%        7.683652e-01
# max        1.821923e+00

# %%
sns.distplot(data['Annual_Income'])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22916\2833962190.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income'])

# %%
ms = MinMaxScaler()
ms.fit(data[['Annual_Income']])
# Out:
# MinMaxScaler()

# %%
data['Annual_Income_min'] = ms.transform(data[['Annual_Income']])

# %%
data.head()
# Out:
#   Loan_ID  Customer_Age  Gender Marital_Status  Dependents Education_Level  \
# 0   L1000          59.0    Male            NaN         1.0     High School
# 1   L1001          49.0  Female         Single         1.0        Graduate
# 2   L1002          35.0    Male         Single         3.0     High School
# 3   L1003          63.0  Female       Divorced         NaN        Graduate
# 4   L1004          28.0    Male         Single         2.0        Graduate
#
#   Employment_Type  Annual_Income  Credit_Score  Loan_Amount  ...  \
# 0             NaN       146114.0         815.0      18403.0  ...
# 1      Unemployed        81135.0         846.0      37097.0  ...
# 2             NaN        70108.0         491.0      18121.0  ...
# 3        Salaried       132296.0         348.0      15966.0  ...
# 4        Salaried       114179.0           NaN      38621.0  ...
#
#    Existing_Loan Loan_Approval_Status Application_Date Last_Payment_Date  \
# 0            Yes                  NaN       2025-11-24        2025-10-02
# 1             No             Approved       2025-02-27        2025-03-05
# 2             No             Rejected       2025-01-13        2025-07-13
# 3            NaN             Approved       2025-05-21        2025-02-10
# 4             No                  NaN       2025-05-06               NaN
#
#   Interest_Rate Number_of_Payments  Account_Balance  Contact_Method  \
# 0           NaN                NaN           1404.0             NaN
# 1         11.00                NaN          41943.0          Branch
# 2         12.08               37.0              NaN          Branch
# 3         12.39               19.0          30189.0          Branch
# 4         10.53               39.0          13763.0           Phone
#
#    Annual_Income_ss Annual_Income_min
# 0          1.729934          0.974521
# 1         -0.142081          0.456017
# 2         -0.459764          0.368026
# 3          1.331844          0.864259
# 4          0.809901          0.719694
#
# [5 rows x 22 columns]

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title("before")
sns.distplot(data['Annual_Income'])

plt.subplot(1,2,2)
plt.title("after")
sns.distplot(data['Annual_Income_min'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22916\97496108.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_22916\97496108.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income_min'])
# <Axes: title={'center': 'after'}, xlabel='Annual_Income_min', ylabel='Density'>

# %%
new_data = {"name":["a","b","c","d","e","a","c"], "eng":[5,3,2,4,6,5,3],'hindi':[2,3,4,5,3,2,4]}

# %%
df = pd.DataFrame(new_data)
df
# Out:
#   name  eng  hindi
# 0    a    5      2
# 1    b    3      3
# 2    c    2      4
# 3    d    4      5
# 4    e    6      3
# 5    a    5      2
# 6    c    3      4

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#   name  eng  hindi
# 0    a    5      2
# 1    b    3      3
# 2    c    2      4
# 3    d    4      5
# 4    e    6      3
# 6    c    3      4

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
data.shape
# Out:
# (50, 22)

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (50, 22)

# %%
data.head()
# Out:
#   Loan_ID  Customer_Age  Gender Marital_Status  Dependents Education_Level  \
# 0   L1000          59.0    Male            NaN         1.0     High School
# 1   L1001          49.0  Female         Single         1.0        Graduate
# 2   L1002          35.0    Male         Single         3.0     High School
# 3   L1003          63.0  Female       Divorced         NaN        Graduate
# 4   L1004          28.0    Male         Single         2.0        Graduate
#
#   Employment_Type  Annual_Income  Credit_Score  Loan_Amount  ...  \
# 0             NaN       146114.0         815.0      18403.0  ...
# 1      Unemployed        81135.0         846.0      37097.0  ...
# 2             NaN        70108.0         491.0      18121.0  ...
# 3        Salaried       132296.0         348.0      15966.0  ...
# 4        Salaried       114179.0           NaN      38621.0  ...
#
#    Existing_Loan Loan_Approval_Status Application_Date Last_Payment_Date  \
# 0            Yes                  NaN       2025-11-24        2025-10-02
# 1             No             Approved       2025-02-27        2025-03-05
# 2             No             Rejected       2025-01-13        2025-07-13
# 3            NaN             Approved       2025-05-21        2025-02-10
# 4             No                  NaN       2025-05-06               NaN
#
#   Interest_Rate Number_of_Payments  Account_Balance  Contact_Method  \
# 0           NaN                NaN           1404.0             NaN
# 1         11.00                NaN          41943.0          Branch
# 2         12.08               37.0              NaN          Branch
# 3         12.39               19.0          30189.0          Branch
# 4         10.53               39.0          13763.0           Phone
#
#    Annual_Income_ss Annual_Income_min
# 0          1.729934          0.974521
# 1         -0.142081          0.456017
# 2         -0.459764          0.368026
# 3          1.331844          0.864259
# 4          0.809901          0.719694
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Loan_ID                50 non-null     object
#  1    Customer_Age          50 non-null     object
#  2    Gender                50 non-null     object
#  3    Marital_Status        50 non-null     object
#  4    Dependents            50 non-null     object
#  5    Education_Level       50 non-null     object
#  6    Employment_Type       50 non-null     object
#  7    Annual_Income         50 non-null     object
#  8    Credit_Score          50 non-null     object
#  9    Loan_Amount           50 non-null     object
#  10   Loan_Term_Months      50 non-null     object
#  11   Property_Area         50 non-null     object
#  12   Existing_Loan         50 non-null     object
#  13   Loan_Approval_Status  50 non-null     object
#  14   Application_Date      50 non-null     object
#  15   Last_Payment_Date     50 non-null     object
#  16   Interest_Rate         50 non-null     object
#  17   Number_of_Payments    50 non-null     object
#  18   Account_Balance       50 non-null     object
#  19   Contact_Method        50 non-null     object
# dtypes: object(20)
# memory usage: 7.9+ KB

# %%
data.isnull().sum()
# Out:
# Loan_ID                  0
#  Customer_Age            0
#  Gender                  0
#  Marital_Status          0
#  Dependents              0
#  Education_Level         0
#  Employment_Type         0
#  Annual_Income           0
#  Credit_Score            0
#  Loan_Amount             0
#  Loan_Term_Months        0
#  Property_Area           0
#  Existing_Loan           0
#  Loan_Approval_Status    0
#  Application_Date        0
#  Last_Payment_Date       0
#  Interest_Rate           0
#  Number_of_Payments      0
#  Account_Balance         0
#  Contact_Method          0
# dtype: int64

# %%
data[' Dependents'].value_counts()
# Remove leading/trailing spaces from column names
data.columns = data.columns.str.strip()

# %%
# Replace empty strings with NaN
data['Dependents'].replace(r'^\s*$', np.nan, regex=True, inplace=True)

# Fill missing values with mode
data['Dependents'].fillna(data['Dependents'].mode()[0], inplace=True)

# Convert to numeric
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12892\2333858441.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Dependents'].replace(r'^\s*$', np.nan, regex=True, inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_12892\2333858441.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Dependents'].fillna(data['Dependents'].mode()[0], inplace=True)

# %%
data['Dependents'].value_counts()
# Out:
# Dependents
# 3.0    17
# 2.0     8
# 0.0     8
# 4.0     8
# 1.0     6
# 9.0     1
# 6.0     1
# 3+      1
# Name: count, dtype: int64

# %%
data['Dependents'].replace('        3+', '3.0',inplace=True)

# %%
data['Dependents'].value_counts()
# Out:
# Dependents
#         3.0    17
#         2.0     8
#         0.0     8
#         4.0     8
#         1.0     6
#         9.0     1
#         6.0     1
# 3.0             1
# Name: count, dtype: int64

# %%
data.head(50)
# Out:
#     Loan_ID   Customer_Age   Gender   Marital_Status   Dependents  \
# 0   L1000             59.0   Male                             1.0
# 1   L1001             49.0   Female   Single                  1.0
# 2   L1002             35.0   Male     Single                  3.0
# 3   L1003             63.0   Female   Divorced
# 4   L1004             28.0   Male     Single                  2.0
# 7   L1007             39.0   Male     Divorced                4.0
# 8   L1008             43.0   Female   Single                  3.0
# 9   L1009             31.0   Male     Single                  4.0
# 10  L1010             31.0            Divorced                4.0
# 11  L1011             44.0   Female   Divorced                2.0
# 13  L1013             60.0                                    3.0
# 14  L1014             44.0   Female   Divorced                4.0
# 15  L1015             23.0            Divorced
# 16  L1016             42.0   Female   Single                  2.0
# 17  L1017             22.0   Female   Divorced
# 18  L1018             44.0            Single                  1.0
# 19  L1019             64.0   Female   Married                 1.0
# 20  L1020             50.0   Female   Divorced                4.0
# 21  L1021             58.0   Male     Married                 9.0
# 22  L1022                    Male                             4.0
# 23  L1023             41.0            Divorced                3.0
# 24  L1024             53.0   Female   Single                  3.0
# 25  L1025             32.0   Female   Married                 3.0
# 27  L1027             64.0   Female   Divorced                3.0
# 28  L1028             45.0   Female   Divorced                2.0
# 29  L1029             47.0   Female   Married                 1.0
# 30  L1030                    Female   Single                  3.0
# 32  L1032             36.0   Female   Married                 0.0
# 33  L1033                    Male     Divorced                0.0
# 34  L1034                    Female   Divorced
# 35  L1035             23.0   Female   Single                  2.0
# 36  L1036             57.0   Male     Divorced                0.0
# 37  L1037                    Female   Single                  3.0
# 38  L1038             41.0   Male     Divorced                4.0
# 39  L1039                    Female
# 41  L1041             38.0   Male     Single                  2.0
# 42  L1042             24.0   Female   Single                  0.0
# 43  L1043             45.0   Male     Married                 6.0
# 44  L1044             34.0   Female   Divorced                0.0
# 45  L1045                    Male                             2.0
# 46  L1046             46.0   Male     Married                 1.0
# 47  L1047             22.0            Divorced                3.0
# 49  L1049             48.0            Single                  0.0
#
#      Education_Level   Employment_Type  Annual_Income   Credit_Score  \
# 0    High School                             146114.0          815.0
# 1    Graduate          Unemployed             81135.0          846.0
# 2    High School                              70108.0          491.0
# 3    Graduate          Salaried              132296.0          348.0
# 4    Graduate          Salaried              114179.0
# 7    Postgraduate      Salaried               43328.0          519.0
# 8                                            139181.0          457.0
# 9    High School       Salaried              111412.0
# 10   High School       Salaried              106831.0          345.0
# 11                     Self-employed          23987.0
# 13   High School       Unemployed             42399.0          398.0
# 14   Graduate          Self-employed         148391.0          336.0
# 15                     Self-employed          66214.0          579.0
# 16   Graduate          Unemployed            119522.0          648.0
# 17   Postgraduate      Unemployed            106416.0
# 18   High School       Self-employed          90271.0          601.0
# 19   High School       Salaried               64064.0          480.0
# 20   High School                             145615.0          398.0
# 21                     Self-employed          90091.0          415.0
# 22   Graduate                                127450.0          490.0
# 23                     Self-employed          60818.0          552.0
# 24   High School                              65525.0          460.0
# 25   Graduate          Salaried               39830.0          555.0
# 27   Postgraduate      Unemployed             26893.0          427.0
# 28   Postgraduate      Salaried              136381.0          317.0
# 29   Postgraduate      Salaried               99909.0          622.0
# 30   Postgraduate      Unemployed             67333.0
# 32   Postgraduate      Unemployed             94290.0          789.0
# 33   Graduate          Self-employed          96213.0          685.0
# 34   High School       Salaried               25895.0          403.0
# 35   Graduate          Unemployed             39738.0          692.0
# 36   Graduate          Salaried               50746.0          545.0
# 37   Graduate          Self-employed          69377.0          475.0
# 38   Postgraduate      Self-employed          68404.0
# 39   Postgraduate      Unemployed             74045.0          776.0
# 41   High School       Salaried              149307.0          707.0
# 42   Postgraduate      Unemployed             59790.0          824.0
# 43                     Salaried              127455.0          805.0
# 44   High School       Salaried               25600.0          335.0
# 45   Postgraduate      Self-employed         114660.0          319.0
# 46   Postgraduate      Self-employed         113179.0          620.0
# 47   Postgraduate                             60764.0          811.0
# 49   Postgraduate      Self-employed          65714.0          770.0
#
#      Loan_Amount   Loan_Term_Months   Property_Area   Existing_Loan  \
# 0        18403.0               12.0   Urban           Yes
# 1        37097.0               24.0   Urban           No
# 2        18121.0               12.0   Urban           No
# 3        15966.0                      Rural
# 4        38621.0               60.0   Rural           No
# 7        36289.0               60.0   Urban           No
# 8                              60.0                   Yes
# 9        47675.0               36.0   Semiurban       Yes
# 10        9777.0               48.0   Rural           Yes
# 11       34749.0               24.0   Urban           Yes
# 13        7491.0               60.0   Rural           Yes
# 14       32236.0               12.0
# 15       19599.0                      Semiurban       No
# 16       24508.0               48.0   Urban           Yes
# 17                             60.0   Rural           Yes
# 18       26606.0               12.0   Semiurban       No
# 19       26699.0               48.0                   No
# 20                             60.0   Rural           No
# 21       37093.0               48.0   Urban           Yes
# 22        9142.0               24.0   Semiurban
# 23       20202.0               24.0   Urban           Yes
# 24       44734.0                      Semiurban       Yes
# 25       12079.0               48.0   Semiurban       Yes
# 27       44567.0               60.0                   No
# 28       33940.0               24.0   Semiurban
# 29       42233.0               24.0   Rural           Yes
# 30       22019.0               60.0   Urban
# 32       31258.0               24.0                   No
# 33       26136.0               48.0   Urban           Yes
# 34       13311.0               24.0   Semiurban       Yes
# 35       22214.0               24.0   Urban           No
# 36       19098.0               36.0   Rural           No
# 37                             24.0   Urban           Yes
# 38       42945.0                                      No
# 39                             60.0   Urban           No
# 41       37217.0                      Urban           No
# 42       13308.0               24.0   Semiurban       Yes
# 43       10949.0               12.0
# 44        6150.0               48.0   Urban           Yes
# 45       28944.0               36.0   Rural           Yes
# 46       39699.0               48.0   Urban           Yes
# 47       14204.0               48.0   Rural           No
# 49       34305.0               36.0   Urban           No
#
#      Loan_Approval_Status   Application_Date   Last_Payment_Date  \
# 0                           2025-11-24         2025-10-02
# 1    Approved               2025-02-27         2025-03-05
# 2    Rejected               2025-01-13         2025-07-13
# 3    Approved               2025-05-21         2025-02-10
# 4                           2025-05-06
# 7    Approved               2025-02-22         2025-11-13
# 8    Approved               2025-12-13         2025-07-05
# 9    Approved               2025-10-07         2025-10-23
# 10   Rejected               2025-02-14         2025-04-09
# 11   Rejected               2025-10-30         2025-12-27
# 13   Rejected               2025-01-17         2025-01-24
# 14   Approved               2025-01-16         2025-12-05
# 15   Rejected               2025-02-17
# 16   Approved                                  2025-05-29
# 17   Approved               2025-04-30         2025-02-10
# 18   Approved                                  2025-04-30
# 19   Approved               2025-11-05         2025-02-21
# 20   Approved               2025-01-14         2025-07-14
# 21   Approved               2025-10-15         2025-05-23
# 22   Rejected               2025-04-12         2025-08-21
# 23   Approved               2025-11-29         2025-11-22
# 24   Rejected               2025-12-26         2025-07-06
# 25   Approved               2025-10-07         2025-03-25
# 27                          2025-04-23
# 28                          2025-08-18         2025-04-18
# 29   Approved                                  2025-12-10
# 30   Approved               2025-05-23         2025-05-17
# 32   Approved               2025-03-23         2025-12-16
# 33   Rejected               2025-12-24
# 34   Approved               2025-08-05
# 35   Rejected               2025-06-24         2025-11-08
# 36   Rejected               2025-05-23         2025-11-22
# 37   Approved
# 38                          2025-04-21         2025-10-01
# 39   Approved               2025-06-22         2025-05-06
# 41                          2025-02-17         2025-08-25
# 42   Approved               2025-07-14         2025-07-14
# 43   Approved               2025-02-19         2025-05-19
# 44   Approved               2025-07-03         2025-11-24
# 45   Rejected                                  2025-12-19
# 46                          2025-11-06         2025-10-13
# 47   Rejected               2025-05-16         2025-04-23
# 49   Approved               2025-08-24         2025-06-16
#
#      Interest_Rate   Number_of_Payments   Account_Balance Contact_Method
# 0                                                  1404.0
# 1            11.0                                 41943.0         Branch
# 2            12.08                 37.0                           Branch
# 3            12.39                 19.0           30189.0         Branch
# 4            10.53                 39.0           13763.0          Phone
# 7            10.72                                10860.0
# 8             8.97                 47.0           39757.0          Phone
# 9             7.89                 38.0           16106.0
# 10           11.75                 28.0           24574.0          Phone
# 11            5.39                 20.0           24524.0         Branch
# 13            4.59                                11916.0         Branch
# 14            8.25                 24.0            5809.0         Branch
# 15                                 39.0           33201.0          Phone
# 16            5.45                 59.0           14456.0          Email
# 17            5.44                                49212.0          Phone
# 18            9.69                 24.0           39765.0          Email
# 19           10.47                 57.0           35816.0         Branch
# 20                                 46.0                            Phone
# 21                                                18100.0         Branch
# 22            7.5                  29.0           22949.0          Phone
# 23            6.79                 16.0            5544.0         Branch
# 24           11.45                 58.0           38744.0
# 25            6.29                 36.0           46543.0          Email
# 27            4.6                  21.0           27657.0          Phone
# 28           12.26                 41.0                            Email
# 29            4.85                 56.0           48198.0          Phone
# 30           11.63                 16.0            8239.0          Email
# 32           12.44                 12.0           44125.0          Phone
# 33                                 29.0           29538.0          Phone
# 34            8.93                 43.0           33049.0          Email
# 35                                 58.0                            Phone
# 36            8.68                                43944.0          Email
# 37            9.54                 22.0            9427.0
# 38           10.07                 32.0           42348.0         Branch
# 39            8.14                 37.0           25285.0         Branch
# 41            9.17                 33.0                           Branch
# 42           11.71                 38.0           23928.0         Branch
# 43            4.86                 60.0           20198.0          Email
# 44            6.75                 24.0                           Branch
# 45           12.1                  44.0           16254.0         Branch
# 46           11.62                 45.0                           Branch
# 47            8.15                 52.0            2252.0         Branch
# 49            6.72                 12.0           13173.0          Email

# %%
sns.displot(data['Annual_Income'])
pltlab.show()

# %%
# Strip extra spaces first
data.columns = data.columns.str.strip()
data['Annual_Income'] = pd.to_numeric(data['Annual_Income'], errors='coerce')

# Check dtype
print(data['Annual_Income'].dtype)

# Ab IQR nikal sakte ho
q1 = data['Annual_Income'].quantile(0.25)
q3 = data['Annual_Income'].quantile(0.75)
iqr = q3 - q1
print(q1, q3, iqr)
# Out:
# float64
# 60791.0 114419.5 53628.5

# %%
min_r = q1-(1.5*iqr)
max_r= q3+(1.5*iqr)
min_r,max_r
# Out:
# (np.float64(-19651.75), np.float64(194862.25))

# %%
#data= data[data["Annual_Income"]<=max_r]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 data= data[data["Annual_Income"]<=max_r]
#
# NameError: name 'max_r' is not defined

# %%
ft = FunctionTransformer(func=np.log1p)

# %%
ft.fit(data[["Annual_Income"]])
data['Annual_Income'] = pd.to_numeric(data['Annual_Income'], errors='coerce')

# %%
data['Annual_Income'].fillna(data['Annual_Income'].mean(), inplace=True)

data['Annual_Income_log'] =  ft.transform(data[["Annual_Income"]])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23104\1232256619.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Annual_Income'].fillna(data['Annual_Income'].mean(), inplace=True)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title("before")
sns.distplot(data['Annual_Income'])

plt.subplot(1,2,2)
plt.title("after")
sns.distplot(data['Annual_Income_log'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23104\397580822.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_23104\397580822.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income_log'])
# <Axes: title={'center': 'after'}, xlabel='Annual_Income_log', ylabel='Density'>

# %%
ft1 = FunctionTransformer(func=lambda x : x**2)
ft1.fit(data[["Annual_Income"]])
data['Annual_Income_log_tf1'] =  ft1.transform(data[["Annual_Income"]])

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title("before")
sns.distplot(data['Annual_Income'])

plt.subplot(1,2,2)
plt.title("after")
sns.distplot(data['Annual_Income_log_tf1'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23104\3028342162.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_23104\3028342162.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual_Income_log_tf1'])
# <Axes: title={'center': 'after'}, xlabel='Annual_Income_log_tf1', ylabel='Density'>

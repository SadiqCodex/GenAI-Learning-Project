# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from mlxtend.plotting import plot_decision_regions
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.tree import plot_tree
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score

# %%
dataset = pd.read_csv("../datasets/subscription_dataset.csv")
dataset.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   56            40342          0
# 1   46           121308          1
# 2   32           121081          1
# 3   25           104045          1
# 4   38            49698          0

# %%
sns.scatterplot(x="Age",y="EstimatedSalary",data=dataset,hue="Purchased")
plt.show()

# %%
dataset.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
x = dataset.iloc[:,:-1]
y = dataset["Purchased"]

# %%
sc = StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
x
# Out:
#           Age  EstimatedSalary
# 0    1.378737        -1.120218
# 1    0.583388         0.851214
# 2   -0.530100         0.845687
# 3   -1.086844         0.430879
# 4   -0.052891        -0.892410
# ..        ...              ...
# 195 -1.245914        -1.176050
# 196  0.821993         0.651748
# 197 -1.404984         0.633803
# 198 -0.848240        -0.072169
# 199 -0.371030         1.333882
#
# [200 rows x 2 columns]

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=52)

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
dt1 = DecisionTreeClassifier(criterion='entropy')
dt1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dt.score(x_test,y_test)*100
# Out:
# 77.5

# %%
dt.score(x_train,y_train)*100
# Out:
# 90.0

# %%
dt1.score(x_test,y_test)*100
# Out:
# 70.0

# %%
dt.predict([[19,20000]])
# Out:
# c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dt)
plt.show()
# Out:
# c:\Users\HP\Desktop\Projects\Machine Learning\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(50,50))
plot_tree(dt)
plt.show()

# %%
for i in range(1,20):
    dt2 = DecisionTreeClassifier(max_depth=i)
    dt2.fit(x_train,y_train)
    print(dt2.score(x_train,y_train)*100,dt2.score(x_test,y_test)*100,i)
# Out:
# 86.25 75.0 1
# 86.25 75.0 2
# 90.0 77.5 3
# 92.5 77.5 4
# 95.0 72.5 5
# 98.75 72.5 6
# 99.375 75.0 7
# 100.0 75.0 8
# 100.0 72.5 9
# 100.0 75.0 10
# 100.0 75.0 11
# 100.0 75.0 12
# 100.0 75.0 13
# 100.0 75.0 14
# 100.0 75.0 15
# 100.0 72.5 16
# 100.0 75.0 17
# 100.0 75.0 18
# 100.0 75.0 19

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("../datasets/house_price.csv")
dataset.head()
# Out:
#    Area_sqft  Bedrooms  Bathrooms  Floors  YearBuilt  Parking  \
# 0        675         5          3       2       2008        0
# 1       1720         5          4       2       1999        2
# 2       1037         5          4       3       1999        1
# 3       3050         3          4       1       2003        1
# 4       2103         2          2       2       2011        1
#
#    Distance_City_km  Crime_Rate  School_Rating  Hospital_Distance_km  \
# 0              20.5         6.1            5.9                  12.6
# 1              21.6         9.0            9.0                   3.9
# 2              20.0         6.4            8.4                  12.2
# 3               5.3         4.0            6.5                   7.7
# 4              29.2         9.9            4.6                   2.8
#
#    Market_Trend  Water_Supply  Electricity  HousePrice
# 0          1.16             1            0     3717905
# 1          1.14             1            0     8623941
# 2          0.89             1            1     4125999
# 3          0.94             1            1    14196859
# 4          1.03             0            0     3751270

# %%
input_data = dataset.iloc[:,:-1]
output_data = dataset["HousePrice"]

# %%
x_train, x_test,y_train,y_test = train_test_split(input_data,output_data,test_size=0.25)P

# %%
y_train,x_train
# Out:
# 12    12173116
# 14    14630716
# 39    10484891
# 20    10167448
# 15     4851780
# 29     6775123
# 18     7732775
# 33    12229753
# 11     4905520
# 4      3751270
# 17     6103969
# 31     4659820
# 41     8636562
# Name: HousePrice, dtype: int64

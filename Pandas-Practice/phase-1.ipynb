# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":["harray","rohan","sadik","subh"],
    "marks":[94,55,99,45],
    "city":["delhi","jaipur","mumbai","bijainagar"],
    
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks        city
# 0  harray     94       delhi
# 1   rohan     55      jaipur
# 2   sadik     99      mumbai
# 3    subh     45  bijainagar

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_no_index.csv',index=False)

# %%
df.head(2)
# Out:
#      name  marks    city
# 0  harray     94   delhi
# 1   rohan     55  jaipur

# %%
df.tail(2)
# Out:
#     name  marks        city
# 2  sadik     99      mumbai
# 3   subh     45  bijainagar

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   73.250000
# std    27.232028
# min    45.000000
# 25%    52.500000
# 50%    74.500000
# 75%    95.250000
# max    99.000000

# %%
train = pd.read_csv('practice.csv')

# %%
train
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  train_no  \
# 0             0             0             0           0     12951
# 1             1             1             1           1     12002
# 2             2             2             2           2     22975
# 3             3             3             3           3     15645
# 4             4             4             4           4     19019
#
#                  train_name  source_station  destination_station  \
# 0   Mumbai Rajdhani Express  Mumbai Central            New Delhi
# 1          Shatabdi Express       New Delhi              Lucknow
# 2  Jaipur Superfast Express          Jaipur        Mumbai Bandra
# 3          Guwahati Express        Guwahati              Kolkata
# 4          Dehradun Express        Dehradun  Delhi Sarai Rohilla
#
#   departure_time arrival_time  distance_km  avg_speed_kmph
# 0          16:00        08:35         1384              50
# ...

# %%
train['avg_speed_kmph'][0] = 50
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18884\4195310370.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   train['avg_speed_kmph'][0] = 50
# ...

# %%
train
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  train_no  \
# 0             0             0             0           0     12951
# 1             1             1             1           1     12002
# 2             2             2             2           2     22975
# 3             3             3             3           3     15645
# 4             4             4             4           4     19019
#
#                  train_name  source_station  destination_station  \
# 0   Mumbai Rajdhani Express  Mumbai Central            New Delhi
# 1          Shatabdi Express       New Delhi              Lucknow
# 2  Jaipur Superfast Express          Jaipur        Mumbai Bandra
# 3          Guwahati Express        Guwahati              Kolkata
# 4          Dehradun Express        Dehradun  Delhi Sarai Rohilla
#
#   departure_time arrival_time  distance_km  avg_speed_kmph
# 0          16:00        08:35         1384              50
# ...

# %%
train.to_csv('practice.csv')

# %%
train.index = ['first','second','third','fourth','fifth']

# %%
train
# Out:
#         Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  train_no  \
# first              0             0             0           0     12951
# second             1             1             1           1     12002
# third              2             2             2           2     22975
# fourth             3             3             3           3     15645
# fifth              4             4             4           4     19019
#
#                       train_name  source_station  destination_station  \
# first    Mumbai Rajdhani Express  Mumbai Central            New Delhi
# second          Shatabdi Express       New Delhi              Lucknow
# third   Jaipur Superfast Express          Jaipur        Mumbai Bandra
# fourth          Guwahati Express        Guwahati              Kolkata
# fifth           Dehradun Express        Dehradun  Delhi Sarai Rohilla
#
#        departure_time arrival_time  distance_km  avg_speed_kmph
# ...

# %%
ser = pd.Series(np.random.rand(34))

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
type(newdf)
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.537421  0.934870  0.321599  0.623413  0.372691
# 1  0.183266  0.644520  0.091791  0.802502  0.750675
# 2  0.412695  0.851438  0.725088  0.916715  0.404327
# 3  0.134150  0.891404  0.028862  0.361823  0.619850
# 4  0.003658  0.143975  0.286651  0.718352  0.347327

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
rows x 5 columns]

# %%
newdf.iloc[0,4]
# Out:
# np.float64(0.3726912571284241)

# %%
newdf.iloc[[0,4],[1,2]]
# Out:
#           B         C
# 0  0.934870  0.321599
# 4  0.143975  0.286651

# %%
newdf.head(3)
# Out:
#           A         B         C         D         E
# 0       999  0.934870  0.321599  0.623413  0.372691
# 1  0.183266  0.644520  0.091791  0.802502  0.750675
# 2  0.412695  0.851438  0.725088  0.916715  0.404327

# %%
newdf.drop(['A','D'],axis=1, inplace=True)

# %%
newdf
# Out:
#             B         C         E
# 0    0.934870  0.321599  0.372691
# 1    0.644520  0.091791  0.750675
# 2    0.851438  0.725088  0.404327
# 3    0.891404  0.028862  0.619850
# 4    0.143975  0.286651  0.347327
# ..        ...       ...       ...
# 329  0.480257  0.763335  0.553894
# 330  0.141090  0.189743  0.168952
# 331  0.178744  0.957286  0.169939
# 332  0.063699  0.267367  0.142912
# 333  0.261799  0.985920  0.719775
#
# [334 rows x 3 columns]

# %%
newdf.head(3)
# Out:
#           B         C         E
# 0  0.934870  0.321599  0.372691
# 1  0.644520  0.091791  0.750675
# 2  0.851438  0.725088  0.404327

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf.head(3)
# Out:
#           B         C         E
# 0  0.934870  0.321599  0.372691
# 1  0.644520  0.091791  0.750675
# 2  0.851438  0.725088  0.404327

# %%
newdf.loc[:,['B']] =56

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: B, Length: 334, dtype: bool

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: B, Length: 334, dtype: bool

# %%
newdf.head()
# Out:
#       B         C         E
# 0  56.0  0.321599  0.372691
# 1  56.0  0.091791  0.750675
# 2  56.0  0.725088  0.404327
# 3  56.0  0.028862  0.619850
# 4  56.0  0.286651  0.347327

# %%
data = {
    "name": ["Harry", "Rohan", "Sadik", "Harry"],
    "toy": ["Car", np.nan, "Train", np.nan],
    "born": [2001, 2000, np.nan, 2003]
}

df = pd.DataFrame(data)

# %%
df.head( )
# Out:
#     name    toy    born
# 0  Harry    Car  2001.0
# 1  Rohan    NaN  2000.0
# 2  Sadik  Train     NaN
# 3  Harry    NaN  2003.0

# %%
df.dropna(how='all',axis=1)
# Out:
#     name    toy    born
# 0  Harry    Car  2001.0
# 1  Rohan    NaN  2000.0
# 2  Sadik  Train     NaN
# 3  Harry    NaN  2003.0

# %%
df.drop_duplicates(subset=['name'],keep=False)
# Out:
#     name    toy    born
# 1  Rohan    NaN  2000.0
# 2  Sadik  Train     NaN

# %%
df.shape
# Out:
# (4, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   toy     2 non-null      object
#  2   born    3 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df['toy'].value_counts(dropna=True)
# Out:
# toy
# Car      1
# Train    1
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#     name    toy   born
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False   True  False

# %%
#create a dataframe which containes only intergers with 3 rows and 2 columns 
#run following dataframe methods on them:

# %%
data = pd.read_excel('data.xlsx')

# %%
data.iloc[0,0]=34

# %%
data.to_excel('data.xlsx')

# %%
data
# Out:
#    Unnamed: 0   Name    Toy    Born        City
# 0          34     34    Car  2001.0       Delhi
# 1           1  Rohan    NaN  2000.0      Jaipur
# 2           2  Sadik  Train     NaN      Mumbai
# 3           3   Subh  Robot  2003.0  Bijainagar

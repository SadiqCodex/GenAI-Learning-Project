# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
array1 = np.array([[1,2,3],[4,5,6]])
array2=np.random.rand(3,3)
array3=np.zeros((4,4))

# %%
np.save('array1.npy',array1)
np.save('array2.npy',array2)
np.save('array3.npy',array3)

# %%
loaded_array1=np.load('array1.npy')
print(loaded_array1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
try:
    logo = mpimg.imread("numpy-logo.png")

    plt.figure(figsize=(10,5))

    # Original
    plt.subplot(1,2,1)
    plt.imshow(logo)
    plt.title("Original Logo")
    plt.axis('off')
    
except FileNotFoundError:
    print("numpy logo file not found")

except ValueError as e:
    print("ValueError:", e)
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\HP\Desktop\Projects\Numpy Project\venv\Lib\site-packages\IPython\core\interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[9], line 2
#     logo = mpimg.imread("numpy-logo.png")
#
#   File c:\Users\HP\Desktop\Projects\Numpy Project\venv\Lib\site-packages\matplotlib\image.py:1520 in imread
#     with img_open(fname) as image:
#
#   File c:\Users\HP\Desktop\Projects\Numpy Project\venv\Lib\site-packages\PIL\ImageFile.py:148 in __init__
#     self._open()
#
#   File c:\Users\HP\Desktop\Projects\Numpy Project\venv\Lib\site-packages\PIL\PngImagePlugin.py:762 in _open
#     raise SyntaxError(msg)
#
#   File <string>
#
# SyntaxError: not a PNG file

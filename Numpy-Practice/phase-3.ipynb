# %% [markdown]
# ## advance operation with business examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# data structure: [restaurent_id, 2021,2022,2023,2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],
    [2, 160000, 190000, 230000, 260000],
    [3, 170000, 200000, 240000, 270000],
    [4, 180000, 210000, 250000, 280000],
    [5, 190000, 220000, 260000, 290000]
])

print("== zamato sales analysis ==")
print("\n sales data shape",sales_data.shape)
print("\n sample data for 1st 3 restau:",sales_data[0:3])
# Out:
# == zamato sales analysis ==
#
#  sales data shape (5, 5)
#
#  sample data for 1st 3 restau: [[     1 150000 180000 220000 250000]
#  [     2 160000 190000 230000 260000]
#  [     3 170000 200000 240000 270000]]

# %%
#total sales per year
print(np.sum(sales_data,axis=0))
yeary_total = np.sum(sales_data[:,1:],axis=0)
print(yeary_total)

# minimum sales per restaurent 
min_sales = np.min(sales_data[:,1:],axis=1)
print(min_sales)

# maximum sales per year
max_sales = np.max(sales_data[:,1:],axis=0)
print(max_sales)

#average sales per restaurent
avg_sales = np.mean(sales_data[:,1:],axis=1)
print(avg_sales)
# Out:
# [     15  850000 1000000 1200000 1350000]
# [ 850000 1000000 1200000 1350000]
# [150000 160000 170000 180000 190000]
# [190000 220000 260000 290000]
# [200000. 210000. 220000. 230000. 240000.]

# %%
cumsum = np.cumsum(sales_data[:,1:],axis=1)
print(cumsum)
plt.figure(figsize=(8,6))
plt.plot(np.mean(cumsum,axis=0))
plt.title("average cumlative sales across all restuarent ")
plt.xlabel("years")
plt.ylabel("sales")
plt.grid(True)
plt.show()
# Out:
# [[150000 330000 550000 800000]
#  [160000 350000 580000 840000]
#  [170000 370000 610000 880000]
#  [180000 390000 640000 920000]
#  [190000 410000 670000 960000]]

# %%
vector1 = np.array([1,2,3,4,5])
vector2 = np.array([6,7,8,9,10])

print("vector add:" ,vector1+ vector2)
print("\n multiplication vector:",vector1*vector2)
print("\n dot product", np.dot(vector1,vector2))
angle = np.arccos(np.dot(vector1,vector2)/( np.linalg.norm(vector1)*np.linalg.norm(vector2)))
print(angle)
# Out:
# vector add: [ 7  9 11 13 15]
#
#  multiplication vector: [ 6 14 24 36 50]
#
#  dot product 130
# 0.26554161733900966

# %%
retuarent_types = np.array(['biryani','chinese','pizza','burger','cafe'])
vectorized_upper = np.vectorize(str.upper)
print("vectorized upper",vectorized_upper(retuarent_types))
# Out:
# vectorized upper ['BIRYANI' 'CHINESE' 'PIZZA' 'BURGER' 'CAFE']

# %%
monthly_avg = sales_data[:,1:]/12
print(monthly_avg)
# Out:
# [[12500.         15000.         18333.33333333 20833.33333333]
#  [13333.33333333 15833.33333333 19166.66666667 21666.66666667]
#  [14166.66666667 16666.66666667 20000.         22500.        ]
#  [15000.         17500.         20833.33333333 23333.33333333]
#  [15833.33333333 18333.33333333 21666.66666667 24166.66666667]]
